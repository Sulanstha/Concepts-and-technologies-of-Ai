# %% [markdown]
# <a href="https://colab.research.google.com/github/Sulanstha/Concepts-and-technologies-of-Ai/blob/main/Worksheet3_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1. Sorting and Subsetting:
# Complete all following Task:
# • Dataset for the Task: "titanic.csv"
# Following task is common for all the problem:
# 1. Load the provided dataset and import in pandas DataFrame.

# %%
data = pd.read_csv("/content/drive/MyDrive/ai/drive-download-20251124T094217Z-1-001-20251208T093421Z-1-001/drive-download-20251124T094217Z-1-001/Titanic-Dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.DataFrame(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Problem 1 - Sorting:
# 1. Create a DataFrame called fare that contains only the Fare column of the Titanic dataset. Print the
# head of the result.

# %%
fare = titanic[['fare']]
fare.head()
# Out:
#       fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %% [markdown]
# 2. Create a DataFrame called class age that contains only the Pclass and Age columns of the Titanic
# dataset, in that order. Print the head of the result.

# %%
class_age = titanic[['pclass', 'age']]
class_age.head()
# Out:
#    pclass   age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %% [markdown]
# 3. Create a DataFrame called survived gender that contains the Survived and Sex columns of the
# Titanic dataset, in that order.Print the head of the result.

# %%
survived_gender = titanic[['survived', 'sex']]
survived_gender.head()
# Out:
#    survived     sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %% [markdown]
# Problem - 2 - Subsetting:
# Complete all the following Task:
# Subsetting Rows:
# 1. Filter the Titanic dataset for cases where the passenger’s fare is greater than 100, assigning it
# to fare gt 100.View the printed result.

# %%
fare = titanic[titanic['fare']> 100]
fare
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 31          1       1  female    NaN      1      0  146.5208        C  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 195         1       1  female  58.00      0      0  146.5208        C  First
# 215         1       1  female  31.00      1      0  113.2750        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 306         1       1  female    NaN      0      0  110.8833        C  First
# 307         1       1  female  17.00      1      0  108.9000        C  First
# 311         1       1  female  18.00      2      2  262.3750        C  First
# 318         1       1  female  31.00      0      2  164.8667        S  First
# 319         1       1  female  40.00      1      1  134.5000        C  First
# 325         1       1  female  36.00      0      0  135.6333        C  First
# 332         0       1    male  38.00      0      1  153.4625        S  First
# 334         1       1  female    NaN      1      0  133.6500        S  First
# 337         1       1  female  41.00      0      0  134.5000        C  First
# 341         1       1  female  24.00      3      2  263.0000        S  First
# 373         0       1    male  22.00      0      0  135.6333        C  First
# 377         0       1    male  27.00      0      2  211.5000        C  First
# 380         1       1  female  42.00      0      0  227.5250        C  First
# 390         1       1    male  36.00      1      2  120.0000        S  First
# 393         1       1  female  23.00      1      0  113.2750        C  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# 438         0       1    male  64.00      1      4  263.0000        S  First
# 498         0       1  female  25.00      1      2  151.5500        S  First
# 505         0       1    male  18.00      1      0  108.9000        C  First
# 527         0       1    male    NaN      0      0  221.7792        S  First
# 537         1       1  female  30.00      0      0  106.4250        C  First
# 544         0       1    male  50.00      1      0  106.4250        C  First
# 550         1       1    male  17.00      0      2  110.8833        C  First
# 557         0       1    male    NaN      0      0  227.5250        C  First
# 581         1       1  female  39.00      1      1  110.8833        C  First
# 609         1       1  female  40.00      0      0  153.4625        S  First
# 659         0       1    male  58.00      0      2  113.2750        C  First
# 660         1       1    male  50.00      2      0  133.6500        S  First
# 679         1       1    male  36.00      0      1  512.3292        C  First
# 689         1       1  female  15.00      0      1  211.3375        S  First
# 698         0       1    male  49.00      1      1  110.8833        C  First
# 700         1       1  female  18.00      1      0  227.5250        C  First
# 708         1       1  female  22.00      0      0  151.5500        S  First
# 716         1       1  female  38.00      0      0  227.5250        C  First
# 730         1       1  female  29.00      0      0  211.3375        S  First
# 737         1       1    male  35.00      0      0  512.3292        C  First
# 742         1       1  female  21.00      2      2  262.3750        C  First
# 763         1       1  female  36.00      1      2  120.0000        S  First
# 779         1       1  female  43.00      0      1  211.3375        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
# 856         1       1  female  45.00      1      1  164.8667        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 27     man        True    C  Southampton    no  False
# 31   woman       False    B    Cherbourg   yes  False
# 88   woman       False    C  Southampton   yes  False
# 118    man        True    B    Cherbourg    no  False
# 195  woman       False    B    Cherbourg   yes   True
# 215  woman       False    D    Cherbourg   yes  False
# 258  woman       False  NaN    Cherbourg   yes   True
# 268  woman       False    C  Southampton   yes  False
# 269  woman       False    C  Southampton   yes   True
# 297  child       False    C  Southampton    no  False
# 299  woman       False    B    Cherbourg   yes  False
# 305  child       False    C  Southampton   yes  False
# 306  woman       False  NaN    Cherbourg   yes   True
# 307  woman       False    C    Cherbourg   yes  False
# 311  woman       False    B    Cherbourg   yes  False
# 318  woman       False    C  Southampton   yes  False
# 319  woman       False    E    Cherbourg   yes  False
# 325  woman       False    C    Cherbourg   yes   True
# 332    man        True    C  Southampton    no  False
# 334  woman       False  NaN  Southampton   yes  False
# 337  woman       False    E    Cherbourg   yes   True
# 341  woman       False    C  Southampton   yes  False
# 373    man        True  NaN    Cherbourg    no   True
# 377    man        True    C    Cherbourg    no  False
# 380  woman       False  NaN    Cherbourg   yes   True
# 390    man        True    B  Southampton   yes  False
# 393  woman       False    D    Cherbourg   yes  False
# 435  child       False    B  Southampton   yes  False
# 438    man        True    C  Southampton    no  False
# 498  woman       False    C  Southampton    no  False
# 505    man        True    C    Cherbourg    no  False
# 527    man        True    C  Southampton    no   True
# 537  woman       False  NaN    Cherbourg   yes   True
# 544    man        True    C    Cherbourg    no  False
# 550    man        True    C    Cherbourg   yes  False
# 557    man        True  NaN    Cherbourg    no   True
# 581  woman       False    C    Cherbourg   yes  False
# 609  woman       False    C  Southampton   yes   True
# 659    man        True    D    Cherbourg    no  False
# 660    man        True  NaN  Southampton   yes  False
# 679    man        True    B    Cherbourg   yes  False
# 689  child       False    B  Southampton   yes  False
# 698    man        True    C    Cherbourg    no  False
# 700  woman       False    C    Cherbourg   yes  False
# 708  woman       False  NaN  Southampton   yes   True
# 716  woman       False    C    Cherbourg   yes   True
# 730  woman       False    B  Southampton   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 742  woman       False    B    Cherbourg   yes  False
# 763  woman       False    B  Southampton   yes  False
# 779  woman       False    B  Southampton   yes  False
# 802  child       False    B  Southampton   yes  False
# 856  woman       False  NaN  Southampton   yes  False

# %% [markdown]
# 2. Filter the Titanic dataset for cases where the passenger’s class (Pclass) is 1, assigning it to
# first class.View the printed result.

# %%
first_class = titanic[titanic['pclass'] == 1]
first_class
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# 23     man        True    A  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [216 rows x 15 columns]

# %% [markdown]
# 3. Filter the Titanic dataset for cases where the passenger’s age is less than 18 and the passenger
# is female (Sex is "female"), assigning it to female under 18. View the printed result.

# %%
female_un18 = titanic[(titanic['age']>18) & (titanic['sex'] == 'female')]
female_un18
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
#
# [193 rows x 15 columns]

# %% [markdown]
# Subsetting Rows by Categorical variables:
# 1. Filter the Titanic dataset for passengers whose Embarked port is either "C" (Cherbourg) or "S"
# (Southampton), assigning the result to embarked c or s. View the printed result.

# %%
embarked_c_or_s = titanic[titanic['embarked'].isin(['C', 'S'])]
embarked_c_or_s
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
#
# [812 rows x 15 columns]

# %% [markdown]
# 2. Filter the Titanic dataset for passengers whose Pclass is in the list [1, 2] (indicating first
# or second class), assigning the result to first second class.View the printed result.

# %%
first_second_class = titanic[titanic['pclass'].isin([1, 2])]
first_second_class
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 9    child       False  NaN    Cherbourg   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 883    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [400 rows x 15 columns]

# %% [markdown]
# 3.2 Exploratory Data Analysis Practice Exercise - 1.
#
#
# Answer the following questions from Dataset:
# Which passenger had the highest fare paid relative to their age?
# To answer the question perform following operations:
# 1. Add a column to the Titanic dataset, fare per year, containing the fare divided by the age of
# the passenger(i.e., Fare/Age).

# %%
median_age = titanic['age'].median()
titanic['age'] = titanic['age'].fillna(median_age)

titanic['fare_per_year'] = titanic['fare'] / titanic['age']

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  fare_per_year
# 0    man        True  NaN  Southampton    no  False       0.329545
# 1  woman       False    C    Cherbourg   yes  False       1.875876
# 2  woman       False  NaN  Southampton   yes   True       0.304808
# 3  woman       False    C  Southampton   yes  False       1.517143
# 4    man        True  NaN  Southampton    no   True       0.230000

# %% [markdown]
# 2. Subset rows where fare per year is higher than 5, assigning this to high fare age.

# %%
high_fare_age = titanic[titanic['fare_per_year'] > 5]
high_fare_age
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 16          0       3    male   2.00      4      1   29.1250        Q   Third
# 27          0       1    male  19.00      3      2  263.0000        S   First
# 31          1       1  female  28.00      1      0  146.5208        C   First
# 43          1       2  female   3.00      1      2   41.5792        C  Second
# ..        ...     ...     ...    ...    ...    ...       ...      ...     ...
# 813         0       3  female   6.00      4      2   31.2750        S   Third
# 824         0       3    male   2.00      4      1   39.6875        S   Third
# 827         1       2    male   1.00      0      2   37.0042        C  Second
# 831         1       2    male   0.83      1      1   18.7500        S  Second
# 850         0       3    male   4.00      4      2   31.2750        S   Third
#
#        who  adult_male deck  embark_town alive  alone  fare_per_year
# 7    child       False  NaN  Southampton    no  False      10.537500
# 16   child       False  NaN   Queenstown    no  False      14.562500
# 27     man        True    C  Southampton    no  False      13.842105
# 31   woman       False    B    Cherbourg   yes  False       5.232886
# 43   child       False  NaN    Cherbourg   yes  False      13.859733
# ..     ...         ...  ...          ...   ...    ...            ...
# 813  child       False  NaN  Southampton    no  False       5.212500
# 824  child       False  NaN  Southampton    no  False      19.843750
# 827  child       False  NaN    Cherbourg   yes  False      37.004200
# 831  child       False  NaN  Southampton   yes  False      22.590361
# 850  child       False  NaN  Southampton    no  False       7.818750
#
# [71 rows x 16 columns]

# %% [markdown]
# 3. Sort high fare age by descending fare per year, assigning this to high fare age srt.

# %%
high_fare_age_srt = high_fare_age.sort_values(by='fare_per_year', ascending=False)
high_fare_age_srt
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 305         1       1    male   0.92      1      2  151.5500        S   First
# 297         0       1  female   2.00      1      2  151.5500        S   First
# 386         0       3    male   1.00      5      2   46.9000        S   Third
# 164         0       3    male   1.00      4      1   39.6875        S   Third
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# ..        ...     ...     ...    ...    ...    ...       ...      ...     ...
# 348         1       3    male   3.00      1      1   15.9000        S   Third
# 31          1       1  female  28.00      1      0  146.5208        C   First
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 813         0       3  female   6.00      4      2   31.2750        S   Third
# 480         0       3    male   9.00      5      2   46.9000        S   Third
#
#        who  adult_male deck  embark_town alive  alone  fare_per_year
# 305  child       False    C  Southampton   yes  False     164.728261
# 297  child       False    C  Southampton    no  False      75.775000
# 386  child       False  NaN  Southampton    no  False      46.900000
# 164  child       False  NaN  Southampton    no  False      39.687500
# 183  child       False    F  Southampton   yes  False      39.000000
# ..     ...         ...  ...          ...   ...    ...            ...
# 348  child       False  NaN  Southampton   yes  False       5.300000
# 31   woman       False    B    Cherbourg   yes  False       5.232886
# 205  child       False    G  Southampton    no  False       5.231250
# 813  child       False  NaN  Southampton    no  False       5.212500
# 480  child       False  NaN  Southampton    no  False       5.211111
#
# [71 rows x 16 columns]

# %% [markdown]
# 4. Select only the Name and fare per year columns of high fare age srt and save the result as result.
# 5. Look at the result.

# %%
result = high_fare_age_srt[['pclass', 'sex', 'age', 'fare_per_year']]
result
result.head(20)
# Out:
#      pclass     sex    age  fare_per_year
# 305       1    male   0.92     164.728261
# 297       1  female   2.00      75.775000
# 386       3    male   1.00      46.900000
# 164       3    male   1.00      39.687500
# 183       2    male   1.00      39.000000
# 827       2    male   1.00      37.004200
# 78        2    male   0.83      34.939759
# 644       3  female   0.75      25.677733
# 469       3  female   0.75      25.677733
# 831       2    male   0.83      22.590361
# 755       2    male   0.67      21.641791
# 788       3    male   1.00      20.575000
# 445       1    male   4.00      20.464575
# 803       3    male   0.42      20.277857
# 824       3    male   2.00      19.843750
# 381       3  female   1.00      15.741700
# 119       3  female   2.00      15.637500
# 737       1    male  35.00      14.637977
# 258       1  female  35.00      14.637977
# 311       1  female  18.00      14.576389

# %% [markdown]
# Which adult male passenger (age ≥ 18 and Sex is ’male’) paid the highest fare relative to their
# class?
# To answer the question perform following operations:
# 1. Add a column to the Titanic dataset, fare per class, containing the fare divided by the passenger
# class i.e. Fare / Pclass.

# %%
titanic['fare_per_class'] = titanic['fare'] / titanic['pclass']
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  fare_per_year  \
# 0    man        True  NaN  Southampton    no  False       0.329545
# 1  woman       False    C    Cherbourg   yes  False       1.875876
# 2  woman       False  NaN  Southampton   yes   True       0.304808
# 3  woman       False    C  Southampton   yes  False       1.517143
# 4    man        True  NaN  Southampton    no   True       0.230000
#
#    fare_per_class
# 0        2.416667
# 1       71.283300
# 2        2.641667
# 3       53.100000
# 4        2.683333

# %% [markdown]
# 2. Subset rows where the passenger is male (Sex is ”male”) and an adult (Age is greater than or equal
# to 18), assigning this to adult males.

# %%
adult_males = titanic[(titanic['sex'] == 'male') & (titanic['age'] >= 18)]
adult_males
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male  28.0      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone  fare_per_year  \
# 0    man        True  NaN  Southampton    no  False       0.329545
# 4    man        True  NaN  Southampton    no   True       0.230000
# 5    man        True  NaN   Queenstown    no   True       0.302082
# 6    man        True    E  Southampton    no   True       0.960417
# 12   man        True  NaN  Southampton    no   True       0.402500
# ..   ...         ...  ...          ...   ...    ...            ...
# 883  man        True  NaN  Southampton    no   True       0.375000
# 884  man        True  NaN  Southampton    no   True       0.282000
# 886  man        True  NaN  Southampton    no   True       0.481481
# 889  man        True    C    Cherbourg   yes   True       1.153846
# 890  man        True  NaN   Queenstown    no   True       0.242188
#
#      fare_per_class
# 0          2.416667
# 4          2.683333
# 5          2.819433
# 6         51.862500
# 12         2.683333
# ..              ...
# 883        5.250000
# 884        2.350000
# 886        6.500000
# 889       30.000000
# 890        2.583333
#
# [519 rows x 17 columns]

# %% [markdown]
# 3. Sort adult males by descending fare per class, assigning this to adult males srt.

# %%
adult_males_srt = adult_males.sort_values(by='fare_per_class', ascending=False)
adult_males_srt
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 737         1       1  male  35.0      0      0  512.3292        C   First
# 679         1       1  male  36.0      0      1  512.3292        C   First
# 27          0       1  male  19.0      3      2  263.0000        S   First
# 438         0       1  male  64.0      1      4  263.0000        S   First
# 118         0       1  male  24.0      0      1  247.5208        C   First
# ..        ...     ...   ...   ...    ...    ...       ...      ...     ...
# 179         0       3  male  36.0      0      0    0.0000        S   Third
# 732         0       2  male  28.0      0      0    0.0000        S  Second
# 822         0       1  male  38.0      0      0    0.0000        S   First
# 806         0       1  male  39.0      0      0    0.0000        S   First
# 815         0       1  male  28.0      0      0    0.0000        S   First
#
#      who  adult_male deck  embark_town alive  alone  fare_per_year  \
# 737  man        True    B    Cherbourg   yes   True      14.637977
# 679  man        True    B    Cherbourg   yes  False      14.231367
# 27   man        True    C  Southampton    no  False      13.842105
# 438  man        True    C  Southampton    no  False       4.109375
# 118  man        True    B    Cherbourg    no  False      10.313367
# ..   ...         ...  ...          ...   ...    ...            ...
# 179  man        True  NaN  Southampton    no   True       0.000000
# 732  man        True  NaN  Southampton    no   True       0.000000
# 822  man        True  NaN  Southampton    no   True       0.000000
# 806  man        True    A  Southampton    no   True       0.000000
# 815  man        True    B  Southampton    no   True       0.000000
#
#      fare_per_class
# 737        512.3292
# 679        512.3292
# 27         263.0000
# 438        263.0000
# 118        247.5208
# ..              ...
# 179          0.0000
# 732          0.0000
# 822          0.0000
# 806          0.0000
# 815          0.0000
#
# [519 rows x 17 columns]

# %% [markdown]
# 4. Select only the Name, Age, and fare per class columns of adult males sr and save the result
# as result.
# 5. Look at the result.

# %%
result = adult_males_srt[['pclass', 'age', 'fare_per_class']]
result
result.head(20)
# Out:
#      pclass   age  fare_per_class
# 737       1  35.0        512.3292
# 679       1  36.0        512.3292
# 27        1  19.0        263.0000
# 438       1  64.0        263.0000
# 118       1  24.0        247.5208
# 557       1  28.0        227.5250
# 527       1  28.0        221.7792
# 377       1  27.0        211.5000
# 332       1  38.0        153.4625
# 373       1  22.0        135.6333
# 660       1  50.0        133.6500
# 390       1  36.0        120.0000
# 659       1  58.0        113.2750
# 698       1  49.0        110.8833
# 505       1  18.0        108.9000
# 544       1  50.0        106.4250
# 484       1  25.0         91.0792
# 245       1  44.0         90.0000
# 224       1  38.0         90.0000
# 453       1  49.0         89.1042

# %% [markdown]
# 3.3 Exploratory Data Analysis with Group-by Method Practice Exercise:
# Based on the dataset Answer the following question:
# What percent of the total fare revenue came from each passenger class?
# To answer the question perform following operation:
# 1. Calculate the total Fare paid across all passengers in the Titanic dataset.

# %%
total_fare = titanic['fare'].sum()
total_fare
# Out:
# np.float64(28693.9493)

# %% [markdown]
# 2. Subset for passengers in first class (Pclass is 1) and calculate their total fare.

# %%
fare_class_1 = titanic[titanic['pclass'] == 1]['fare'].sum()
fare_class_1
# Out:
# np.float64(18177.4125)

# %% [markdown]
# 3. Do the same for second class (Pclass is 2) and third class (Pclass is 3).

# %%
fare_class_2 = titanic[titanic['pclass'] == 2]['fare'].sum()
fare_class_2
# Out:
# np.float64(3801.8417)

# %%
fare_class_3 = titanic[titanic['pclass'] == 3]['fare'].sum()
fare_class_3
# Out:
# np.float64(6714.6951)

# %% [markdown]
# 4. Combine the fare totals from first, second, and third classes into a list.

# %%
fare_list = [fare_class_1, fare_class_2, fare_class_3]
fare_list
# Out:
# [np.float64(18177.4125), np.float64(3801.8417), np.float64(6714.6951)]

# %% [markdown]
# 5. Divide the totals for each class by the overall total fare to get the proportion of fare revenue by class.

# %%
proportion_by_class = [fare / total_fare for fare in fare_list]
proportion_by_class
# Out:
# [np.float64(0.6334928771899656),
#  np.float64(0.1324962855496507),
#  np.float64(0.23401083726038366)]

# %% [markdown]
# What percent of the total number of passengers on the Titanic belonged to each age group
# (e.g., child, adult, senior)?
# To answer the question perform following operation:
# 1. Create a new column, age group, that categorizes passengers into "child" (age < 18), "adult" (age
# 18{64), and "senior" (age 65 and above).

# %%
# Fill missing Age values
median_age = titanic['age'].median()
titanic['age'] = titanic['age'].fillna(median_age)

titanic['age_group'] = pd.cut(
    titanic['age'],
    bins=[0, 18, 64, 150],
    labels=['child', 'adult', 'senior'],
    right=False   # makes 18 included in adult
)

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  fare_per_year  \
# 0    man        True  NaN  Southampton    no  False       0.329545
# 1  woman       False    C    Cherbourg   yes  False       1.875876
# 2  woman       False  NaN  Southampton   yes   True       0.304808
# 3  woman       False    C  Southampton   yes  False       1.517143
# 4    man        True  NaN  Southampton    no   True       0.230000
#
#    fare_per_class age_group
# 0        2.416667     adult
# 1       71.283300     adult
# 2        2.641667     adult
# 3       53.100000     adult
# 4        2.683333     adult

# %% [markdown]
# 2. Calculate the total number of passengers on the Titanic.

# %%
total_passengers = len(titanic)
total_passengers
# Out:
# 891

# %% [markdown]
# 3. Count the number of passengers in each age group.

# %%
age_group_counts = titanic['age_group'].value_counts()
age_group_counts
# Out:
# age_group
# adult     765
# child     113
# senior     13
# Name: count, dtype: int64

# %% [markdown]
# 4. Divide the count of each age group by the total number of passengers to get the proportion of passengers
# in each age group.

# %%
age_group_proportion = age_group_counts / total_passengers
age_group_proportion
# Out:
# age_group
# adult     0.858586
# child     0.126824
# senior    0.014590
# Name: count, dtype: float64

# %% [markdown]
# 5. Display the proportion as a percentage.

# %%
age_group_percentage = age_group_proportion * 100
age_group_percentage
# Out:
# age_group
# adult     85.858586
# child     12.682379
# senior     1.459035
# Name: count, dtype: float64
